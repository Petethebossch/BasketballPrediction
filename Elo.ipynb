# %%
import pandas as pd
import os
import chardet
import numpy as np
import glob
import math

# %%
# Define the path where your CSV files are located
csv_path = "Data/*.csv"

# Get a list of all CSV file paths matching the pattern
csv_files = glob.glob(csv_path)

# Initialize an empty dictionary to store the DataFrames
dataframes = {}

# Read each CSV file into a DataFrame and store it in the dictionary
for file in csv_files:
    # Extract the file name without the extension as the dictionary key
    file_name = file.split(".",1)[0]
    file_name = file.split("/",1)[1]
        # Read the CSV file into a DataFrame
    with open(file, 'rb') as f:
        result = chardet.detect(f.read())
    encoding = result['encoding']
    df = pd.read_csv(file,encoding=encoding)
        
        # Store the DataFrame in the dictionary
    dataframes[file_name] = df

# Access the individual DataFrames by their respective keys
print(dataframes)
# Out:
# {'Cities':      CityID         City State
# 0      4001      Abilene    TX
# 1      4002        Akron    OH
# 2      4003       Albany    NY
# 3      4004  Albuquerque    NM
# 4      4005    Allentown    PA
# ..      ...          ...   ...
# 467    4490       Easton    MA
# 468    4491        Laval    QC
# 469    4492       London    GB
# 470    4493        Union    NJ
# 471    4494        Kihei    HI
#
# [472 rows x 3 columns], 'Conferences':     ConfAbbrev                                   Description
# 0        a_sun                       Atlantic Sun Conference
# 1        a_ten                        Atlantic 10 Conference
# 2          aac                  American Athletic Conference
# 3          acc                     Atlantic Coast Conference
# 4          aec                       America East Conference
# 5          asc                     American South Conference
# 6          awc                      American West Conference
# ...

# %%
maleGames = pd.DataFrame()
maleGames = pd.concat([dataframes["MRegularSeasonDetailedResults"],dataframes["MNCAATourneyDetailedResults"]], ignore_index=True)

# %%
pd.set_option('display.max_columns', 500)
maleGames
maleGames["CityID"] = 0
for x in range(34074,len(maleGames)):
    print(x)
    done = 0
    currGame = maleGames.iloc[x]
    hi = len(dataframes["MGameCities"])
    lo = 0
    if(currGame["Season"]>2009):
        while(not done and hi != lo):
            mid = int((hi+lo)/2)
            if(currGame["Season"]>dataframes["MGameCities"].iloc[mid]["Season"]):
                lo = mid
            elif(currGame["Season"]<dataframes["MGameCities"].iloc[mid]["Season"]):
                hi = mid
            else:
                if(currGame["DayNum"]>dataframes["MGameCities"].iloc[mid]["DayNum"]):
                    lo = mid
                elif(currGame["DayNum"]<dataframes["MGameCities"].iloc[mid]["DayNum"]):
                    hi = mid
                else:
                    if(currGame["WTeamID"]>dataframes["MGameCities"].iloc[mid]["WTeamID"]):
                        lo = mid
                    elif(currGame["WTeamID"]<dataframes["MGameCities"].iloc[mid]["WTeamID"]):
                        hi = mid
                    else:
                        maleGames.loc[x, "CityID"] = dataframes["MGameCities"].iloc[mid]["CityID"]
                        done = 1
# Out:
# 34074
# 34075
# 34076
# 34077
# 34078
# 34079
# 34080
# 34081
# 34082
# 34083
# 34084
# 34085
# 34086
# 34087
# 34088
# 34089
# 34090
# 34091
# 34092
# 34093
# 34094
# 34095
# 34096
# 34097
# 34098
# 34099
# 34100
# 34101
# 34102
# 34103
# 34104
# 34105
# 34106
# 34107
# 34108
# 34109
# 34110
# 34111
# 34112
# 34113
# 34114
# 34115
# 34116
# 34117
# 34118
# 34119
# 34120
# 34121
# 34122
# 34123
# 34124
# 34125
# 34126
# 34127
# 34128
# 34129
# 34130
# 34131
# 34132
# 34133
# 34134
# 34135
# 34136
# 34137
# 34138
# 34139
# 34140
# 34141
# 34142
# 34143
# 34144
# 34145
# 34146
# 34147
# 34148
# 34149
# 34150
# 34151
# 34152
# 34153
# 34154
# 34155
# 34156
# 34157
# 34158
# 34159
# 34160
# 34161
# 34162
# 34163
# 34164
# 34165
# 34166
# 34167
# 34168
# 34169
# 34170
# 34171
# 34172
# 34173
# 34174
# 34175
# 34176
# 34177
# 34178
# 34179
# 34180
# 34181
# 34182
# 34183
# 34184
# 34185
# 34186
# 34187
# 34188
# 34189
# 34190
# 34191
# 34192
# 34193
# 34194
# 34195
# 34196
# 34197
# 34198
# ...

# %%
maleGames = maleGames[maleGames["CityID"]!= 0]
maleGames
# Out:
#         Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 34074     2010       7     1143      75     1293      70    H      0    24
# 34075     2010       7     1314      88     1198      72    H      0    34
# 34076     2010       7     1326     100     1108      60    H      0    39
# 34077     2010       7     1393      75     1107      43    H      0    29
# 34078     2010       9     1143      95     1178      61    H      0    29
# ...        ...     ...      ...     ...      ...     ...  ...    ...   ...
# 108877    2022     146     1242      76     1274      50    N      0    29
# 108878    2022     146     1314      69     1389      49    N      0    25
# 108879    2022     152     1242      81     1437      65    N      0    29
# 108880    2022     152     1314      81     1181      77    N      0    27
# 108881    2022     154     1242      72     1314      69    N      0    29
#
# ...

# %%
column_name_mapping = {
    'WTeamID': 'Team1',
    'WScore' : 'Team1Score',
    'LTeamID': 'Team2',
    'LScore': 'Team2Score',
    'WLoc': 'Team1Loc',
    'WFGM': 'Team1FGM',
    'WFGA': 'Team1FGA',
    'WFGM3': 'Team1FGM3',
    'WFGA3': 'Team1FGA3',
    'WFTM': 'Team1FTM',
    'WOR': 'Team1OR',
    'WDR': 'Team1DR',
    'WAst': 'Team1Ast',
    'WTO': 'Team1TO',
    'WStl': 'Team1Stl',
    'WBlk': 'Team1Blk',
    'WPF': 'Team1PF',
    'LFGM': 'Team2FGM',
    'LFGA': 'Team2FGA',
    'LFGM3': 'Team2FGM3',
    'LFGA3': 'Team2FGA3',
    'LFTM': 'Team2FTM',
    'LOR': 'Team2OR',
    'LDR': 'Team2DR',
    'LAst': 'Team2Ast',
    'LTO': 'Team2TO',
    'LStl': 'Team2Stl',
    'LBlk': 'Team2Blk',
    'LPF': 'Team2PF'
}
newDf = pd.DataFrame(np.repeat(maleGames.values, 2, axis=0))
for x in range(1,len(newDf),2):
    newDf.loc[x,2],newDf.loc[x,4] = newDf.loc[x,4],newDf.loc[x,2]
    newDf.loc[x,3],newDf.loc[x,5] = newDf.loc[x,5],newDf.loc[x,3]
    for y in range(8,21):
       newDf.loc[x,y],newDf.loc[x,y+13] = newDf.loc[x,y+13],newDf.loc[x,y]    
newDf.columns = maleGames.columns
newDf.rename(columns=column_name_mapping, inplace=True)
for x in range(1,len(newDf),2):
    if(newDf.loc[x-1,"Team1Loc"]=="H"):
        newDf.loc[x,"Team1Loc"] = "A"
    if(newDf.loc[x-1,"Team1Loc"]=="A"):
        newDf.loc[x,"Team1Loc"] = "H"
newDf["Win"] = 0
newDf["PointDif"] = 0
for x in range(len(newDf)):
    if x % 2 == 0:
        newDf.loc[x, "Win"] = 1

    newDf.loc[x, "PointDif"] = newDf.loc[x, "Team1Score"] - newDf.loc[x, "Team2Score"]

# %%
newDf
# Out:
#        Season DayNum Team1 Team1Score Team2 Team2Score Team1Loc NumOT  \
# 0        2010      7  1143         75  1293         70        H     0
# 1        2010      7  1293         70  1143         75        A     0
# 2        2010      7  1314         88  1198         72        H     0
# 3        2010      7  1198         72  1314         88        A     0
# 4        2010      7  1326        100  1108         60        H     0
# ...       ...    ...   ...        ...   ...        ...      ...   ...
# 148715   2022    152  1437         65  1242         81        N     0
# 148716   2022    152  1314         81  1181         77        N     0
# 148717   2022    152  1181         77  1314         81        N     0
# 148718   2022    154  1242         72  1314         69        N     0
# 148719   2022    154  1314         69  1242         72        N     0
#
#        Team1FGM Team1FGA Team1FGM3 Team1FGA3 Team1FTM WFTA Team1OR Team1DR  \
# ...

# %%
def expected_win_rate(team1,team2):
    return 1/(1+10**((team2-team1)/400))

# %%
losses = []
for day_multiplier in range(20,30):
    day_multiplier = day_multiplier/10
    for multiplier in range(6,14):
        print(day_multiplier,multiplier)
        total_loss = 0
        teams_elo = {key: 1500 for key in teams.keys()}
        newDf["Team1_elo_pre"] = 0
        newDf["Team2_elo_pre"] = 0
        newDf["Team1_elo_post"] = 0
        newDf["Team2_elo_post"] = 0
        for x in range(0,len(newDf),2):
            team1 = newDf["Team1"].iloc[x]
            team2 = newDf["Team2"].iloc[x]
            newDf.loc[x,"Team1_elo_pre"] = teams_elo[team1]
            newDf.loc[x,"Team2_elo_pre"] = teams_elo[team2]
            win_rate = expected_win_rate(teams_elo[team1],teams_elo[team2])
            total_loss = total_loss + (1-win_rate)**2
            teams_elo[team1] = teams_elo[team1] + (1+(day_multiplier/154)*(154-newDf["DayNum"].iloc[x]))*math.log(newDf["PointDif"].iloc[x])*multiplier*(1-win_rate)
            teams_elo[team2] = teams_elo[team2] + (1+(day_multiplier/154)*(154-newDf["DayNum"].iloc[x]))*math.log(newDf["PointDif"].iloc[x])*multiplier*(win_rate-1)
            newDf.loc[x,"Team1_elo_post"] = teams_elo[team1]
            newDf.loc[x,"Team2_elo_post"] = teams_elo[team2]
            newDf.loc[x+1,"Team1_elo_pre"] = newDf.loc[x,"Team2_elo_pre"]
            newDf.loc[x+1,"Team2_elo_pre"] = newDf.loc[x,"Team1_elo_pre"]
            newDf.loc[x+1,"Team1_elo_post"] = newDf.loc[x,"Team2_elo_post"]
            newDf.loc[x+1,"Team2_elo_post"] = newDf.loc[x,"Team1_elo_post"]
        losses.append(total_loss)
# Out:
# 2.0 6
# 2.0 7
# 2.0 8
# 2.0 9
# 2.0 10
# 2.0 11
# 2.0 12
# 2.0 13
# 2.1 6
# 2.1 7
# 2.1 8
# 2.1 9
# 2.1 10
# 2.1 11
# 2.1 12
# 2.1 13
# 2.2 6
# 2.2 7
# 2.2 8
# 2.2 9
# 2.2 10
# 2.2 11
# 2.2 12
# 2.2 13
# 2.3 6
# 2.3 7
# 2.3 8
# 2.3 9
# 2.3 10
# 2.3 11
# 2.3 12
# 2.3 13
# 2.4 6
# 2.4 7
# 2.4 8
# 2.4 9
# 2.4 10
# 2.4 11
# 2.4 12
# 2.4 13
# 2.5 6
# 2.5 7
# 2.5 8
# 2.5 9
# 2.5 10
# 2.5 11
# 2.5 12
# 2.5 13
# 2.6 6
# 2.6 7
# 2.6 8
# 2.6 9
# 2.6 10
# 2.6 11
# 2.6 12
# 2.6 13
# 2.7 6
# 2.7 7
# 2.7 8
# 2.7 9
# 2.7 10
# 2.7 11
# 2.7 12
# 2.7 13
# 2.8 6
# 2.8 7
# 2.8 8
# 2.8 9
# 2.8 10
# 2.8 11
# 2.8 12
# 2.8 13
# 2.9 6
# 2.9 7
# 2.9 8
# 2.9 9
# 2.9 10
# 2.9 11
# 2.9 12
# 2.9 13

# %%
data_array = np.array(losses)

# Reshape the array into a 5x10 matrix
data_matrix = data_array.reshape(8, 10)

# Create column names
column_names = [str(i/10+2) for i in range(10)]

# Create a DataFrame with the data and column names
df = pd.DataFrame(data_matrix, columns=column_names)

new_column = list(range(6, 14))
df.insert(0, 'Multiplier', new_column)

# Print the DataFrame
df
# Out:
#    Multiplier           2.0           2.1           2.2           2.3  \
# 0           6  14456.986260  14409.987016  14381.824822  14367.717751
# 1           7  14376.043580  14364.397455  14363.557983  14371.296952
# 2           8  14363.371358  14373.456640  14390.456371  14413.156154
# 3           9  14395.583676  14420.541118  14417.751937  14381.157524
# 4          10  14409.682125  14375.649975  14360.008997  14358.085869
# 5          11  14357.570744  14358.050170  14369.066927  14388.431464
# 6          12  14371.918896  14393.577728  14421.947283  14455.832302
# 7          13  14429.835678  14465.927599  14383.250509  14359.333320
#
#             2.4           2.5           2.6           2.7           2.8  \
# 0  14364.473623  14369.855234  14382.233671  14400.386145  14446.047098
# 1  14385.991451  14406.422964  14435.892730  14394.128783  14371.015422
# 2  14426.475518  14387.304103  14366.694374  14359.933037  14363.868575
# ...

# %%
low = 10000000
for x in range(0,len(losses)):
    if(losses[x]<low):
        low = losses[x]
print(low)
# Out:
# 14353.489213719542

# %%
March_Madness = [
    [1192, 1411],
    [1113, 1305],
    [1401, 1283],
    [1338, 1280],
    [1222, 1297],
    [1120, 1234],
    [1274, 1179],
    [1231, 1245],
    [1338, 1235],
    [1462, 1244],
    [1336, 1401],
    [1400, 1159],
    [1242, 1224],
    [1116, 1228],
    [1388, 1433],
    [1163, 1233],
    [1395, 1113],
    [1211, 1213],
    [1321, 1129],
    [1417, 1421],
    [1192, 1345],
    [1194, 1272],
    [1181, 1331],
    [1397, 1256],
    [1246, 1344],
    [1243, 1286],
    [1277, 1425],
    [1266, 1436],
    [1104, 1401],
    [1268, 1452],
    [1361, 1158],
    [1202, 1438],
    [1166, 1301],
    [1124, 1364],
    [1281, 1429],
    [1343, 1112],
    [1222, 1120],
    [1274, 1231],
    [1462, 1338],
    [1400, 1336],
    [1116, 1242],
    [1163, 1291],
    [1211, 1395],
    [1417, 1321],
    [1194, 1192],
    [1397, 1181],
    [1243, 1246],
    [1277, 1266],
    [1104, 1268],
    [1361, 1202],
    [1166, 1124],
    [1343, 1281],
    [1274, 1222],
    [1400, 1462],
    [1163, 1116],
    [1211, 1417],
    [1194, 1397],
    [1243, 1277],
    [1361, 1104],
    [1166, 1343],
    [1274, 1400],
    [1163, 1211],
    [1194, 1243],
    [1361, 1166],
    [1361, 1194],
    [1163, 1274],
    [1163, 1361]
]

# %%
average_loss = 0
for x in range(0,len(March_Madness)):
    average_loss += (1-expected_win_rate(teams_elo[March_Madness[x][0]],teams_elo[March_Madness[x][1]]))**2
average_loss = average_loss/len(March_Madness)/2

# %%
print(average_loss)
# Out:
# 0.11079332617832052
